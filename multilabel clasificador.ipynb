# %%
path = './multilabel/stackoverflow_perguntas.csv'

# %%
import pandas as pd
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (5408, 2)

# %%
df.sample(10)
# Out:
#                                               Perguntas            Tags
# 4335  Estou trabalhando em um projeto em Rails, onde...          jquery
# 2153  Existe algum evento CODE  que identifique quan...          jquery
# 2916  Estou lendo um livro de Angular 5 + Asp.NET Co...         angular
# 2182  Tenho um conjunto de divs abaixo do header (ca...     jquery html
# 4838  tenho o seguinte código:   CODE   ele recebe v...            html
# 821   Bom dia pessoal.  Seguinte, preciso fazer com ...  jquery angular
# 4002  Ola gostaria de fazer um metodo onde o usuario...            html
# 5050  Estou tentando atualizar um gráfico utilizando...         angular
# 1257  Olá, quero criar uma barrinha que mostre a dur...           html
# 2852  Tenho lido bastante sobre algumas ferramentas ...           html

# %%
df['Tags'].unique()
# Out:
# array(['node.js', 'jquery', 'html', 'html angular ', 'html ', 'angular',
#        'angular ', 'jquery html  ', 'jquery ', 'jquery html',
#        'jquery html ', 'html angular', 'angular node.js ', 'html  ',
#        'jquery html angular', 'node.js ', 'html jquery', 'html jquery ',
#        'jquery angular  ', 'html node.js', 'jquery  ', 'angular node.js',
#        'jquery angular', 'html node.js ', 'jquery node.js ', 'angular  ',
#        'jquery angular ', 'jquery html angular ', 'node.js html ',
#        ' node.js', 'node.js html', 'html angular  ', 'jquery node.js',
#        'angular html', 'html angular  node.js', 'jquery html node.js',
#        'html angular node.js'], dtype=object)

# %%
#vamos criar um modo de converter de string para inteiros binarios
# Removendo espaços em excesso nas strings
df['Tags'] = df['Tags'].str.strip()

# Separando as tags em colunas binárias
tags_dummies = df['Tags'].str.get_dummies(sep=' ')

# Adicionando as colunas resultantes ao DataFrame original
df = pd.concat([df, tags_dummies], axis=1)

# %%
df.sample(3)
# Out:
#                                               Perguntas          Tags  \
# 2422  Tenho uma modal que quando o cursor do mouse s...          html
# 2753  Estou fazendo uma requisição ajax, o qual reto...        jquery
# 5166  Observei que a página tem o seguinte código pa...  html angular
#
#       angular  html  jquery  node.js
# 2422        0     1       0        0
# 2753        0     0       1        0
# 5166        1     1       0        0

# %%
df['juncao'] = list(zip(df['angular'], df['html'], df['jquery'], df['node.js']))

# %%
df.sample(10)
# Out:
#                                               Perguntas            Tags  \
# 4155  Tenho um input simples que recebe uma data, co...  jquery angular
# 539   Boa tarde,  Gente eu estou iniciando meus estu...         node.js
# 3619  é possível que um campo texto receba somente o...            html
# 3215  Como eu faço para remover tudo o que tem antes...          jquery
# 1137  Quero criar um banner de publicidades de uma e...         angular
# 310   O que usar para criar relatórios com Angular e...    html angular
# 2718  CODE   CODE         Gostaria de saber se é pos...            html
# 1477  Olá, queria saber como faz para fazer quando a...          jquery
# 5382  Tenho uma variável onde armazena o resultado d...          jquery
# 4944  Tenho uma variável que chama todos os nomes de...          jquery
#
#       angular  html  jquery  node.js        juncao
# 4155        1     0       1        0  (1, 0, 1, 0)
# 539         0     0       0        1  (0, 0, 0, 1)
# 3619        0     1       0        0  (0, 1, 0, 0)
# 3215        0     0       1        0  (0, 0, 1, 0)
# 1137        1     0       0        0  (1, 0, 0, 0)
# 310         1     1       0        0  (1, 1, 0, 0)
# 2718        0     1       0        0  (0, 1, 0, 0)
# 1477        0     0       1        0  (0, 0, 1, 0)
# 5382        0     0       1        0  (0, 0, 1, 0)
# 4944        0     0       1        0  (0, 0, 1, 0)

# %%
# quais classificadores usar para multilabel

# %%
# hora do modelo

# %%
from sklearn.model_selection import train_test_split
X = df['Perguntas']
y = df['juncao']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# TF-IDF
# texto para numeros - A principal característica do TF-IDF é ser uma pontuação proporcional à frequência da palavra
# no texto e equilibrada pela frequência no corpus, ou seja, palavras que se repetem muito tendem a ter pontuações 
# menores e são menos relevantes no processo de classificação.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=5000,max_df=0.85) # maximo  vetor de palavras e remover palavras com muita frequencia

# %%
vectorizer.fit(df.Perguntas)
# Out:
# TfidfVectorizer(max_df=0.85, max_features=5000)

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['00', '000', '01', ..., 'único', 'únicos', 'útil'], dtype=object)

# %%
X_train_tfidf = vectorizer.transform(X_train)
X_test_tfidf  = vectorizer.transform(X_test)
